# %%
# Dependency imports
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# Notebook customizations
from IPython.display import display
pd.options.display.max_columns = None

# %%
properties_2016_df = pd.read_csv("./data/properties_2016.csv", encoding="latin1")
properties_2016_df.head()
# Out:
# /Users/viveckh/Knowledgent/HousingPricePrediction/.venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# ...

# %%
train_2016_df = pd.read_csv("./data/train_2016_v2.csv", encoding="latin1", parse_dates=['transactiondate'])
train_2016_df.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
sns.relplot(kind="line", x='bedroomcnt', y='bathroomcnt', data=properties_2016_df)
